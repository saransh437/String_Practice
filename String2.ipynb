# %%
# 1.
a = "abc"
print(a.upper())

# %%
# 2.
a = "Abc"
print(a.lower())

# %%
# 3
a = "abc abc"
print(a.title())

# %%
# 4
a = "abc"
print(a.capitalize())

# %%
# 5
a = "  abc  "
print(a.strip())

# %%
# 6
a = "  abc"
print(a.lstrip())

# %%
# 7
a = "abc  "
print(a.rstrip())

# %%
# 8
a = 'hello guys'
print(a.split())

# %%
# 9
st = 'this is a sentence'.split()
print(st)
sent = " ".join(st)
print(sent)

# %%
# 10
a = "saransh soni"
print(a.replace('soni','bansal'))
# Out:
# saransh bansal

# %%
# 11
a = 'This is python'
print(a.find("is"))
# Out:
# 2

# %%
# 12
a = 'saransh'
print(a.count('a'))
# Out:
# 2

# %%
# 13
a = 'Hi saransh'
print(a.startswith('Hi'))
# Out:
# False

# %%
# 14
a = "saransh@gmail.com"
if a.endswith('.com'):
  print('valid gmail')

# %%
# 15
a = input('enter a string:')
if a.isalpha() :
  print('string contain char')
# Out:
# enter a string:sara12

# %%
# 16
a = input('enter a string:')
if a.isdigit() :
  print('string contain digit')
# Out:
# enter a string:sara12

# %%
# 17
a = input('enter a string:')
if a.isspace() :
  print('string contain space')
# Out:
# enter a string:sara 12

# %%
# 18
a = input('enter a string:')
if a.isalnum() :
  print('string contain char and numeric')
# Out:
# enter a string:sara
# string contain char and numeric

# %%
# 19
a = input('ENter a string:')
b = a.title()
print(b.count('The'))
# Out:
# ENter a string:this is the data science domain
# 1

# %%
# 20
# a.
a = input('Enter a string:')
b = ('a','e','i','o','u')
if a.startswith(b):
  print('its start with vowel')
# Out:
# Enter a string:aman
# its start with vowel

# %%
# 20 b.
a = input('Enter a string:')
b = ('a','e','i','o','u')
if not a.endswith(b):
  print('its end with consonant')
# Out:
# Enter a string:study at regi
